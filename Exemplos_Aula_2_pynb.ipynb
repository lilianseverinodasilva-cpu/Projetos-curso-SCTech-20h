# %% [markdown]
# <a href="https://colab.research.google.com/github/lilianseverinodasilva-cpu/Projetos-curso-SCTech-20h/blob/main/Exemplos_Aula_2_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
produtos = ["notebook","mouse","teclado","monitor"]

# %%
produtos[0]
# Out:
# 'notebook'

# %%
produtos[3]
# Out:
# 'monitor'

# %%
produtos[-1]
# Out:
# 'monitor'

# %%
produtos_selecionados = produtos[0:2]

# %%
print (produtos_selecionados)
# Out:
# ['notebook', 'mouse']

# %%
review_score = int(input("Qual a sua nota?"))
if review_score == 5:
  print ("Excelente")
elif review_score == 4:
  print ("pode melhorar")
else:
  print ("Viiiixe")
# Out:
# Qual a sua nota?3
# Viiiixe

# %%
for produto in produtos:
  print (f'Processando":{produto}')
# Out:
# Processando":notebook
# Processando":mouse
# Processando":teclado
# Processando":monitor

# %%
for i, produto in enumerate (produtos):
  print (f'{i+1}.{produto}')
# Out:
# 1.notebook
# 2.mouse
# 3.teclado
# 4.monitor

# %%
precos = [23,56,78,56,89,76]
precos_com_iva = []
precos_com_iva = [p*1.10 for p in precos]
print (precos_com_iva)
# Out:
# [25.3, 61.60000000000001, 85.80000000000001, 61.60000000000001, 97.9, 83.60000000000001]

# %%
precos = [23,56,7448,56,8500,76]
precos_com_iva = []
caros = [p for p in precos if p > 150]
print (caros)
# Out:
# [7448, 8500]

# %%
import kagglehub
path = kagglehub.dataset_download("olistbr/brazilian-ecommerce")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'brazilian-ecommerce' dataset.
# Path to dataset files: /kaggle/input/brazilian-ecommerce

# %%
df_orders_items = pd.read_csv("/kaggle/input/brazilian-ecommerce/olist_order_items_dataset.csv")

# %%
df_orders_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df_products = pd.read_csv("/kaggle/input/brazilian-ecommerce/olist_products_dataset.csv")

# %%
df_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df_products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
df_categories = pd.read_csv("/kaggle/input/brazilian-ecommerce/product_category_name_translation.csv")
df_categories.tail()
# Out:
#             product_category_name product_category_name_english
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services

# %%
vendas_vendedores = df_orders_items.groupby("seller_id")["price"].sum()
vendas_vendedores
# Out:
# seller_id
# 0015a82c2db000af6aaaf3ae2ecb0532     2685.00
# 001cca7ae9ae17fb1caed9dfb1094831    25080.03
# 001e6ad469a905060d959994f1b41e4f      250.00
# 002100f778ceb8431b7a1020ff7ab48f     1234.50
# 003554e2dce176b5555353e4f3555ac8      120.00
#                                       ...
# ffcfefa19b08742c5d315f2791395ee5       69.90
# ffdd9f82b9a447f6f8d4b91554cc7dd3     2101.20
# ffeee66ac5d5a62fe688b9d26f83f534     1839.86
# fffd5413c0700ac820c7069d66d98c89     9062.30
# ffff564a4f9085cd26170f4732393726     1426.30
# Name: price, Length: 3095, dtype: float64

# %%
ranking_vendedores = vendas_vendedores.sort_values(ascending=False)
print (ranking_vendedores)
# Out:
# seller_id
# 4869f7a5dfa277a7dca6462dcf3b52b2    229472.63
# 53243585a1d6dc2643021fd1853d8905    222776.05
# 4a3ca9315b744ce9f8e9374361493884    200472.92
# fa1c13f2614d7b5c4749cbc52fecda94    194042.03
# 7c67e1448b00f6e969d365cea6b010ab    187923.89
#                                       ...
# 34aefe746cd81b7f3b23253ea28bef39         8.00
# 702835e4b785b67a084280efca355756         7.60
# 1fa2d3def6adfa70e58c276bb64fe5bb         6.90
# 77128dec4bec4878c37ab7d6169d6f26         6.50
# cf6f6bc4df3999b9c6440f124fb2f687         3.50
# Name: price, Length: 3095, dtype: float64

# %%
df_orders_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
most_selled_products = df_orders_items.groupby("product_id")["price"].count()
most_selled_products = most_selled_products.sort_values(ascending=False)
print (most_selled_products)
# Out:
# product_id
# aca2eb7d00ea1a7b8ebd4e68314663af    527
# 99a4788cb24856965c36a24e339b6058    488
# 422879e10f46682990de24d770e7f83d    484
# 389d119b48cf3043d311335e499d9c6b    392
# 368c6c730842d78016ad823897a372db    388
#                                    ...
# ffd7628b0b0b98ebc549e8e4c54a59af      1
# ffd63ee42a5c8cc5a15a1c8e2aa50011      1
# 002959d7a0b0990fe2d69988affcbc80      1
# 002552c0663708129c0019cc97552d7d      1
# 0021a87d4997a48b6cef1665602be0f5      1
# Name: price, Length: 32951, dtype: int64

# %%
pip install nbstripout

# %%
# !nbstripout meu_notebook.ipynb
# Out:
# Could not strip 'meu_notebook.ipynb': file not found
